# %% [markdown]
# # 🎬 Análisis Exploratorio de Datos (Netflix Dataset)
#
# **Autor:** Cecilia Torales
# **Fecha:** Octubre 2025
# **Herramientas:** Python, Pandas, Google Colab
#
# ---
#
# ## 🧭 Importación y carga de datos

# %%
# Importar la librería Pandas
import pandas as pd

# Importamos el Dataset Netflix
df = pd.read_csv("https://raw.githubusercontent.com/CeciliaCTorales/Netflix-Data-Analisys/refs/heads/main/netflix_titles.csv")

# %%
# Ver información general del Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ## 🔍 Exploración inicial (EDA básica)
#   - Duplicaods: no hay
#   - Nulos:
#     - Hay 5 columnas con valores nulos
#     - director, cast, country, rating y duration

# %%
# Rápida exploración de DUPLICADOS
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Rápida exploración de NULOS
#df[df.isnull().any(axis=1)]
df.isnull().sum()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
# Visualizar columnas
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Observar o filtrar una columna
df['country'].sample(5)
# Out:
# 1024    United States
# 8007        Australia
# 4714            India
# 2831              NaN
# 3163            India
# Name: country, dtype: object

# %%
# Observar o filtrar más de una columna
df[['country', 'description']].sample(5)
# Out:
#             country                                        description
# 274   United States  They’re not friends, but when their husbands l...
# 2290          India  When London-based doctor Manu reluctantly retu...
# 3130        Nigeria  For a group of charismatic undergraduates, the...
# 1712          India  From a resurfaced sex tape to a rogue suitcase...
# 6818  United States  When a billionaire sets out to take over the w...

# %%
# Agregamos ordenamiento
df[['description', 'country']].sort_values(by = 'country', ascending=True )
# Out:
#                                             description            country
# 365   After a decade in prison, a Palestinian man wi...  , France, Algeria
# 193   A young private’s assignment to capture army d...      , South Korea
# 6400  When Julia literally falls into Alejandro's ba...          Argentina
# 5001  An Argentine comedian espouses the values of f...          Argentina
# 2894  A determined woman works to rid an Argentine s...          Argentina
# ...                                                 ...                ...
# 8718  A look into the journey of influential strengt...                NaN
# 8759  From a bubble-shaped palace to an island built...                NaN
# 8783  Friends Mai, Oto and Vik's games at the park b...                NaN
# 8785  With the mind of a human being, and the body o...                NaN
# 8803  While living alone in a spooky town, a young g...                NaN
#
# [8807 rows x 2 columns]

# %% [markdown]
# ## 🎯 Selección y filtrado

# %%
# Seleccionar filas específicas, en este caso las primeras 5, es equivalente al head(5)
df.loc[1:5]
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast       country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN
# 3                                                NaN           NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...         India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...           NaN
#
#            date_added  release_year rating   duration  \
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
# Seleccionar un subset (filas y columnas específicas)
df.loc[1:5 ,['title','type']]
# Out:
#                    title     type
# 1          Blood & Water  TV Show
# 2              Ganglands  TV Show
# 3  Jailbirds New Orleans  TV Show
# 4           Kota Factory  TV Show
# 5          Midnight Mass  TV Show

# %%
# Filtrar los registros que sean Movie
df[df['type'] == 'Movie']
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
# Listar los registros cuyo campo country es Argentina
df[df['country'] == "Argentina"]
# Out:
#      show_id     type                                          title  \
# 275     s276  TV Show                                    The Kingdom
# 303     s304    Movie                           Esperando la carroza
# 434     s435  TV Show                                         Okupas
# 673     s674  TV Show                              No Time for Shame
# 709     s710  TV Show                                    Millennials
# 769     s770    Movie                       From Stress to Happiness
# 838     s839    Movie                          Soy Rada: Serendipity
# 1417   s1418    Movie                                      Al acecho
# 1657   s1658    Movie                               Notes for My Son
# 1713   s1714    Movie                         Memories of a Teenager
# 1733   s1734  TV Show                Carmel: Who Killed Maria Marta?
# 1792   s1793    Movie            Guillermo Vilas: Settling the Score
# 1876   s1877    Movie                              Palermo Hollywood
# ...

# %%
# Listar los registros (movies/TV Shows) cuyo "release_year" es anterior al 2020
#df['type'].unique() los tipos solo son movies/TV Shows
df[df['release_year'] < 2020].sort_values(by='release_year', ascending = False)
# Out:
#      show_id     type                                          title  \
# 3729   s3730    Movie                                       Rakkhosh
# 3742   s3743  TV Show                         Somewhere Only We Know
# 3743   s3744  TV Show                           The Alcàsser Murders
# 3745   s3746  TV Show                 Awake: The Million Dollar Game
# 3746   s3747  TV Show                                     Black Spot
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#                              director  \
# 3729  Abhijit Kokate, Srivinay Salian
# 3742                              NaN
# ...

# %%
# Listar los registros (movies/TV Shows) cuyo date_added es anterior al 2020
df[df['date_added'] < 2020]
#analizamos el error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1757704597.py in <cell line: 0>()
#       1 # Listar los registros (movies/TV Shows) cuyo date_added es anterior al 2020
# ----> 2 df[df['date_added'] < 2020]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __lt__(self, other)
#      46     @unpack_zerodim_and_defer("__lt__")
#      47     def __lt__(self, other):
# ---> 48         return self._cmp_method(other, operator.lt)
#      49
#      50     @unpack_zerodim_and_defer("__le__")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
# ...

# %%
# Comparar el dtype de las columnas "release_year" y "date_added"
df[['release_year', 'date_added']].dtypes
# Out:
# release_year     int64
# date_added      object
# dtype: object

# %%
# Listar registros random
df[['release_year', 'date_added']].sample(5)
# Out:
#       release_year        date_added
# 3405          2019  October 18, 2019
# 3638          2019     July 26, 2019
# 7503          2005   January 1, 2020
# 977           2016    April 23, 2021
# 4186          2016  January 15, 2019

# %%
# Convertimos el dtype de "date_added" a datetime en una nueva columna date_added_dt
df['date_added_dt'] = pd.to_datetime(df['date_added'].str.strip())

# %%
# Validamos el nuevo dtype
df['date_added_dt'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
# Ejecutamos nuevamente la consulta
df[df['date_added_dt'].dt.year < 2020].sort_values(by='date_added_dt', ascending=False)
# Out:
#      show_id     type                        title              director  \
# 3077   s3078    Movie                       Aaviri             Ravi Babu
# 7830   s7831    Movie            Ramji Londonwaley          Sanjay Dayma
# 6604   s6605    Movie                      Dhamaal           Indra Kumar
# 6577   s6578    Movie     Deadline: Sirf 24 Ghante          Tanveer Khan
# 6485   s6486    Movie                Chupke Chupke  Hrishikesh Mukherjee
# ...      ...      ...                          ...                   ...
# 7370   s7371    Movie  Mad Ron's Prevues from Hell            Jim Monaco
# 5955   s5956    Movie                     Splatter             Joe Dante
# 5956   s5957    Movie      Just Another Love Story          Ole Bornedal
# 6611   s6612  TV Show              Dinner for Five                   NaN
# 5957   s5958    Movie         To and From New York  Sorin Dan Mihalcescu
#
#                                                    cast        country  \
# ...

# %%
# Filtrar las películas Argentinas cuyo time_added sea posterior al 2020
df[ (df['date_added_dt'].dt.year > 2020)  & (df['country'] == 'Argentina')][['type', 'country', 'date_added_dt','title']]
# Out:
#          type    country date_added_dt                     title
# 275   TV Show  Argentina    2021-08-13               The Kingdom
# 303     Movie  Argentina    2021-08-05      Esperando la carroza
# 434   TV Show  Argentina    2021-07-20                    Okupas
# 673   TV Show  Argentina    2021-06-19         No Time for Shame
# 709   TV Show  Argentina    2021-06-16               Millennials
# 769     Movie  Argentina    2021-06-03  From Stress to Happiness
# 838     Movie  Argentina    2021-05-27     Soy Rada: Serendipity
# 1417    Movie  Argentina    2021-01-12                 Al acecho

# %%
# Listar las registros cuyo title incluya las palabra "cielo"
df[df['title'].str.contains('cielo' , case=False)]
# Out:
#      show_id     type                   title               director  \
# 2599   s2600  TV Show  El señor de los Cielos                    NaN
# 3104   s3105    Movie    Como caído del cielo         Pepe Bojórquez
# 6400   s6401    Movie         Caida del Cielo  Néstor Sánchez Sotelo
#
#                                                    cast  \
# 2599  Rafael Amaya, Ximena Herrera, Robinson Díaz, R...
# 3104  Omar Chaparro, Ana Claudia Talancón, Stephanie...
# 6400  Muriel Santa Ana, Peto Menahem, Héctor Díaz, S...
#
#                               country         date_added  release_year rating  \
# 2599  United States, Mexico, Colombia     April 30, 2020          2019  TV-MA
# 3104                           Mexico  December 24, 2019          2019  TV-14
# 6400                        Argentina   January 20, 2017          2016  TV-MA
#
#        duration                                          listed_in  \
# 2599  7 Seasons  Crime TV Shows, International TV Shows, Spanis...
# ...

# %%
# Filtrar las películas cuyo director contiene Johnson

df[(df['type'] == 'Movie') & (df['director'].str.contains("johnson", case=False))][['type','title','director']]
# Out:
#        type                                   title  \
# 0     Movie                    Dick Johnson Is Dead
# 829   Movie                        Dog Gone Trouble
# 846   Movie                                    Home
# 2052  Movie                        Love, Guaranteed
# 2083  Movie                    The Debt Collector 2
# ...     ...                                     ...
# 7369  Movie                               Mad Money
# 7622  Movie                             Nowhere Boy
# 7912  Movie                                S.W.A.T.
# 7946  Movie                              Savage Dog
# 8082  Movie  Star Wars: Episode VIII: The Last Jedi
#
#                              director
# 0                     Kirsten Johnson
# 829                     Kevin Johnson
# 846                       Tim Johnson
# 2052              Mark Steven Johnson
# 2083                 Jesse V. Johnson
# ...                               ...
# 7369  Callie Khouri, Jesse V. Johnson
# ...

# %%
# Listar los registros (movies/TV shows) de ["Argentina", "Mexico", "Chile"]
df[df['country'].isin(['Argentina','Mexico','Chile'])]
# Out:
#      show_id     type                 title            director  \
# 17       s18  TV Show       Falsa identidad                 NaN
# 275     s276  TV Show           The Kingdom                 NaN
# 282     s283    Movie  La diosa del asfalto    Julián Hernández
# 303     s304    Movie  Esperando la carroza     Alejandro Doria
# 311     s312  TV Show             Control Z                 NaN
# ...      ...      ...                   ...                 ...
# 8185   s8186    Movie            The Aerial       Esteban Sapir
# 8358   s8359    Movie          The Incident         Isaac Ezban
# 8508   s8509    Movie          The Similars         Isaac Ezban
# 8699   s8700    Movie            Warehoused  Jack Zagha Kababie
# 8768   s8769    Movie     Y Tu Mamá También      Alfonso Cuarón
#
#                                                    cast    country  \
# 17    Luis Ernesto Franco, Camila Sodi, Sergio Goyri...     Mexico
# ...

# %%
# Usar la IA para mejorar el filtro y que no sea case sensitive
countries = ["Argentina", "Mexico", "Chile"]
countries = [country.lower() for country in countries]
df[df["country"].str.lower().isin(countries)]
# Out:
#      show_id     type                 title            director  \
# 17       s18  TV Show       Falsa identidad                 NaN
# 275     s276  TV Show           The Kingdom                 NaN
# 282     s283    Movie  La diosa del asfalto    Julián Hernández
# 303     s304    Movie  Esperando la carroza     Alejandro Doria
# 311     s312  TV Show             Control Z                 NaN
# ...      ...      ...                   ...                 ...
# 8185   s8186    Movie            The Aerial       Esteban Sapir
# 8358   s8359    Movie          The Incident         Isaac Ezban
# 8508   s8509    Movie          The Similars         Isaac Ezban
# 8699   s8700    Movie            Warehoused  Jack Zagha Kababie
# 8768   s8769    Movie     Y Tu Mamá También      Alfonso Cuarón
#
#                                                    cast    country  \
# 17    Luis Ernesto Franco, Camila Sodi, Sergio Goyri...     Mexico
# ...
